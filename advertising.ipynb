# %%
import pandas as pd

# %%
data=pd.read_csv("advertising.csv")
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.dropna()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(data,kind="reg", diag_kws={"color": "Green"})
plt.show()

# %%
sns.barplot(data=data)
# Out:
# <Axes: >

# %%
sns.histplot(x="TV",data=data,bins=20,color="green",kde=True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x="Radio",data=data,kde=True,bins=20,color="indigo")
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x="Newspaper",data=data,kde=True,bins=20,color="purple")
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.heatmap(data.corr(),cmap="magma",linewidth=0.5,annot=True,fmt=".2f")
plt.show()

# %%
X = data[['TV', 'Radio', 'Newspaper']]
y = data['Sales']
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2)
train_data= X_train.join(y_train)
train_data
# Out:
#         TV  Radio  Newspaper  Sales
# 37    74.7   49.4       45.7   14.7
# 135   48.3   47.0        8.5   11.6
# 31   112.9   17.4       38.6   11.9
# 80    76.4   26.7       22.3   11.8
# 33   265.6   20.0        0.3   17.4
# ..     ...    ...        ...    ...
# 118  125.7   36.9       79.2   15.9
# 147  243.2   49.0       44.3   25.4
# 194  149.7   35.6        6.0   17.3
# 90   134.3    4.9        9.3   14.0
# 178  276.7    2.3       23.7   16.8
#
# [160 rows x 4 columns]

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 136   25.6   39.0        9.3
# 113  209.6   20.6       10.7
# 95   163.3   31.6       52.9
# 100  222.4    4.3       49.8
# 189   18.7   12.1       23.4
# 32    97.2    1.5       30.0
# 171  164.5   20.9       47.4
# 96   197.6    3.5        5.9
# 82    75.3   20.3       32.5
# 12    23.8   35.1       65.9
# 139  184.9   43.9        1.7
# 45   175.1   22.5       31.5
# 103  187.9   17.2       17.9
# 117   76.4    0.8       14.8
# 144   96.2   14.8       38.9
# 28   248.8   27.1       22.9
# 153  171.3   39.7       37.7
# 77   120.5   28.5       14.2
# 9    199.8    2.6       21.2
# 87   110.7   40.6       63.2
# 178  276.7    2.3       23.7
# 191   75.5   10.8        6.0
# 85   193.2   18.4       65.7
# 130    0.7   39.6        8.7
# 121   18.8   21.7       50.4
# 59   210.7   29.5        9.3
# 27   240.1   16.7       22.9
# 132    8.4   27.2        2.1
# 150  280.7   13.9       37.0
# 36   266.9   43.8        5.0
# 69   216.8   43.9       27.2
# 159  131.7   18.4       34.6
# 78     5.4   29.9        9.4
# 40   202.5   22.3       31.6
# 2     17.2   45.9       69.3
# 185  205.0   45.1       19.6
# 88    88.3   25.5       73.4
# 73   129.4    5.7       31.3
# 20   218.4   27.7       53.4
# 196   94.2    4.9        8.1

# %%
y_test
# Out:
# 165    16.9
# 126     6.6
# 147    25.4
# 177    16.7
# 23     20.5
# 96     16.7
# 113    20.9
# 93     22.2
# 150    16.1
# 120    15.5
# 56      5.5
# 84     21.7
# 190    10.8
# 63     14.0
# 86     12.0
# 95     16.9
# 168    17.1
# 69     22.3
# 32     13.2
# 124    19.7
# 128    24.7
# 148    10.9
# 49      9.7
# 192     5.9
# 189     6.7
# 21     17.5
# 98     25.4
# 24      9.7
# 76      6.9
# 106     7.2
# 59     18.4
# 83     13.6
# 160    16.4
# 154    20.6
# 9      15.6
# 101    23.8
# 170     8.4
# 143    10.4
# 46     10.6
# 91      7.3
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = train_data[['TV', 'Radio','Newspaper']], train_data['Sales']

#Build a Linear Regression model
fitted_model = LinearRegression()
#Train the model
fitted_model.fit(X_train,y_train)
#Make predictions
y_pred = fitted_model.predict(x_test)
y_pred
# Out:
# array([18.26079213,  9.29557254, 23.02948492, 14.81555926, 18.81498485,
#        15.62425854, 18.0499145 , 22.40739689, 21.43937125, 15.26783072,
#         8.09676577, 20.72444559, 10.87018852, 13.14997406, 11.56801176,
#        17.00252963, 19.05311687, 20.94061196, 10.17633989, 20.83659186,
#        21.45140355, 10.75764873,  9.6250084 ,  6.11684086,  6.94305756,
#        18.08830803, 24.92650486,  9.31544058,  6.3320837 ,  7.22451547,
#        19.00152375, 13.02606444, 15.9489333 , 16.90913152, 15.77751144,
#        25.087831  ,  8.54800562, 11.0398689 , 10.6691884 ,  6.48233832])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

MSE =  mean_squared_error(y_test, y_pred) 
MAE = mean_absolute_error(y_test, y_pred)
R2_Score = r2_score(y_test, y_pred)

print('Mean squared error value is: ', MSE)
print('Mean absolute error value is: ', MAE)
print('R2 score value is: ', R2_Score)
# Out:
# Mean squared error value is:  2.8192167514598574
# Mean absolute error value is:  1.1655750755235328
# R2 score value is:  0.9184924208272178

# %%
plt.figure(figsize=(10, 5))
plt.scatter(y_test, y_pred,alpha=0.8,color="Red")
plt.plot([min(y_test),max(y_test)],[min(y_test),max(y_test)],color='red',linewidth=1)
plt.title('Actual vs Predicted values for Sales')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.show()

# %%
data = {'TV': [230.1], 'Radio': [37.8] ,'Newspaper': [69.2]}
trial_data = pd.DataFrame(data)
# Predict rating using trial data
predict_rating = fitted_model.predict(trial_data)
print('Predicted Rating for trial data: ',predict_rating[0])
# Out:
# Predicted Rating for trial data:  21.386462460551165
